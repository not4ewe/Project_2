# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file_beers = "Resources/beers.csv"
beers_df = pd.read_csv(csv_file_beers)
beers_df.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
newbeer_df = beers_df[['abv', 'id', 'name','style', 'brewery_id', 'ounces']].copy()

newbeer_df.head()
# Out:
#      abv    id                 name                           style  \
# 0  0.050  1436             Pub Beer             American Pale Lager
# 1  0.066  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  2264  Rise of the Phoenix                    American IPA
# 3  0.090  2263             Sinister  American Double / Imperial IPA
# 4  0.075  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
csv_file_breweries = "Resources/breweries.csv"
breweries_df = pd.read_csv(csv_file_breweries)
breweries_df.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# ### Create new data with select columns

# %%
newbrew_df = breweries_df[['Unnamed: 0','name', 'city', 'state']].copy()
newbrew_df = newbrew_df.rename(columns={'name':'brewery_name','Unnamed: 0':'brewery_id'})
newbrew_df.set_index('brewery_id')
# Out:
#                              brewery_name           city state
# brewery_id
# 0                      NorthGate Brewing     Minneapolis    MN
# 1               Against the Grain Brewery     Louisville    KY
# 2                Jack's Abby Craft Lagers     Framingham    MA
# 3               Mike Hess Brewing Company      San Diego    CA
# 4                 Fort Point Beer Company  San Francisco    CA
# ...                                   ...            ...   ...
# 553                   Covington Brewhouse      Covington    LA
# 554                       Dave's Brewfarm         Wilson    WI
# 555                 Ukiah Brewing Company          Ukiah    CA
# 556               Butternuts Beer and Ale  Garrattsville    NY
# 557         Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 3 columns]

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/Project_2"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['breweries', 'beers', 'merged', 'results']

# %%
newbrew_df.to_csv(r"Resources/breweries2.csv")
newbeer_df.to_csv(r"Resources/beers2.csv")

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
newbrew_df.to_sql(name='breweries', con=engine, if_exists='append', index=False)

# %%
newbeer_df.to_sql(name='beers', con=engine, if_exists='append', index=True)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from beers', con=engine).head()
# Out:
#    index    abv    id                 name                           style  \
# 0      0  0.050  1436             Pub Beer             American Pale Lager
# 1      1  0.066  2265          Devil's Cup         American Pale Ale (APA)
# 2      2  0.071  2264  Rise of the Phoenix                    American IPA
# 3      3  0.090  2263             Sinister  American Double / Imperial IPA
# 4      4  0.075  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408      12
# 1         177      12
# 2         177      12
# 3         177      12
# 4         177      12

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from breweries', con=engine).head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
merged_df = pd.merge(newbrew_df,newbeer_df,on='brewery_id')
merged_df
# Out:
#       brewery_id                   brewery_name           city state    abv  \
# 0              0             NorthGate Brewing     Minneapolis    MN  0.045
# 1              0             NorthGate Brewing     Minneapolis    MN  0.049
# 2              0             NorthGate Brewing     Minneapolis    MN  0.048
# 3              0             NorthGate Brewing     Minneapolis    MN  0.060
# 4              0             NorthGate Brewing     Minneapolis    MN  0.060
# ...          ...                            ...            ...   ...    ...
# 2405         556        Butternuts Beer and Ale  Garrattsville    NY  0.049
# 2406         556        Butternuts Beer and Ale  Garrattsville    NY  0.068
# 2407         556        Butternuts Beer and Ale  Garrattsville    NY  0.049
# 2408         556        Butternuts Beer and Ale  Garrattsville    NY  0.043
# 2409         557  Sleeping Lady Brewing Company      Anchorage    AK  0.049
#
#         id                       name                    style  ounces
# 0     2692               Get Together             American IPA    16.0
# 1     2691              Maggie's Leap       Milk / Sweet Stout    16.0
# 2     2690                 Wall's End        English Brown Ale    16.0
# 3     2689                    Pumpion              Pumpkin Ale    16.0
# 4     2688                 Stronghold          American Porter    16.0
# ...    ...                        ...                      ...     ...
# 2405    52   Heinnieweisse Weissebier               Hefeweizen    12.0
# 2406    51            Snapperhead IPA             American IPA    12.0
# 2407    50          Moo Thunder Stout       Milk / Sweet Stout    12.0
# 2408    49          Porkslap Pale Ale  American Pale Ale (APA)    12.0
# 2409    30  Urban Wilderness Pale Ale         English Pale Ale    12.0
#
# [2410 rows x 9 columns]

# %%
merged_df.to_sql(name='merged', con=engine, if_exists='append', index=True)
